# %% [markdown]
# # 📘 Dummy Estimators: Baseline Evaluation in Predictive Modeling
#
# ---
#
# ## 🔹 Concept and Purpose
#
# In machine learning, **dummy estimators** are intentionally simplistic models that generate predictions using naive strategies (e.g., random guessing, predicting the most frequent label, or using the mean of the target variable).
#
# - Their primary role is **not to solve the predictive task**, but to serve as a **baseline reference**.
# - This ensures that more complex models (e.g., logistic regression, random forest, neural network) provide **added value beyond trivial heuristics**.
#
# ---
#
# ## 🔹 Types of Dummy Strategies
#
# ### Classification
#
# - **Most Frequent Strategy**
#
# $$
# \hat{y} = \arg \max_{c \in C} P(y = c)
# $$
#
# Always predicts the majority class.
#
# - **Stratified Strategy**
#
# $$
# P(\hat{y} = c) = \frac{\text{count}(y = c)}{N}
# $$
#
# Predicts classes proportionally to their observed frequencies.
#
# - **Uniform Strategy**
#
# $$
# P(\hat{y} = c) = \frac{1}{|C|}
# $$
#
# Predicts classes uniformly at random.
#
# - **Constant Strategy**
# Always predicts a pre-specified label.
#
# ---
#
# ### Regression
#
# - **Mean Strategy**
#
# $$
# \hat{y} = \frac{1}{N} \sum_{i=1}^N y_i
# $$
#
# Predicts the mean of the training targets.
#
# - **Median Strategy**
#
# $$
# \hat{y} = \text{median}(y_1, y_2, \dots, y_N)
# $$
#
# Predicts the median of the training targets.
#
# - **Quantile Strategy**
# Predicts a fixed quantile of the training targets.
#
# - **Constant Strategy**
# Always predicts a user-defined constant.
#
# ---
#
# ## 🔹 Mathematical and Statistical Framing
#
# Dummy estimators function as **statistical null models**:
#
# - **Classification baseline accuracy**
#
# $$
# Acc_{\text{baseline}} = \max_c \frac{\text{count}(y = c)}{N}
# $$
#
# Equivalent to the relative frequency of the majority class.
#
# - **Regression minimization properties**
#
# The mean predictor minimizes **Mean Squared Error (MSE):**
#
# $$
# \hat{y}_{mean} = \arg \min_{\hat{y}} \sum (y_i - \hat{y})^2
# $$
#
# The median predictor minimizes **Mean Absolute Error (MAE):**
#
# $$
# \hat{y}_{median} = \arg \min_{\hat{y}} \sum |y_i - \hat{y}|
# $$
#
# ➡️ Thus, dummy estimators are **mathematically optimal** under trivial constraints.
#
# ---
#
# ## 🔹 Why They Matter
#
# - **Benchmarking** → Ensures advanced models surpass trivial baselines.
# - **Sanity Check** → Detects data leakage or flawed evaluation (if a complex model underperforms a dummy).
# - **Interpretability** → Provides **lower bounds** for expected performance, especially in noisy datasets.
#
# ---
#
# ## 🔹 Academic Context
#
# - **Dietterich (1998)**: Highlighted the importance of baselines in preventing misleading claims of improvement.
# - **Hastie, Tibshirani & Friedman (2009)**: Discussed mean and median predictors as natural **risk minimizers** under squared and absolute loss.
# - **Scikit-learn Documentation**: Institutionalizes dummy estimators as part of the evaluation API.
#
# ---
#
# ## ✅ Verdict
#
# Dummy estimators are not trivial add-ons.
# They are **statistically grounded reference models** that enforce **rigorous empirical validation**, ensuring that machine learning research and applications demonstrate **true predictive value beyond naive baselines**.

# %% [markdown]
# # 📐 Mathematical & Statistical Foundations of Dummy Estimators
#
# ---
#
# ## 1. Dummy Classifiers
#
# ### a. Most Frequent Class Baseline
# Always predicts the **majority class**:
#
# $$
# \hat{y} = \arg \max_{c \in C} P(y = c)
# $$
#
# Where:
# - $C$: set of possible classes
# - $P(y = c)$: empirical frequency of class $c$
#
# ---
#
# ### b. Stratified Baseline
# Predicts classes randomly according to their frequency distribution:
#
# $$
# P(\hat{y} = c) = \frac{n_c}{N}
# $$
#
# Where:
# - $n_c$: number of samples in class $c$
# - $N$: total number of samples
#
# ---
#
# ### c. Uniform Baseline
# Predicts classes **uniformly at random**:
#
# $$
# P(\hat{y} = c) = \frac{1}{|C|}
# $$
#
# ---
#
# ### d. Evaluation Metrics (Classification)
#
# - **Accuracy**
#
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# - **Precision**
#
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# - **Recall (Sensitivity)**
#
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# - **F1 Score**
#
# $$
# F_1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# - **ROC AUC**
#
# $$
# AUC = \int_0^1 TPR(FPR) \, dFPR
# $$
#
# Where:
# - $TP, TN, FP, FN$: true/false positives/negatives
# - $TPR = \frac{TP}{TP+FN}$ (true positive rate)
# - $FPR = \frac{FP}{FP+TN}$ (false positive rate)
#
# ---
#
# ## 2. Dummy Regressors
#
# ### a. Mean Baseline
# Always predicts the **mean** of the training targets:
#
# $$
# \hat{y} = \frac{1}{N} \sum_{i=1}^N y_i
# $$
#
# ---
#
# ### b. Median Baseline
# Always predicts the **median** of the training targets:
#
# $$
# \hat{y} = \text{median}(y_1, y_2, \dots, y_N)
# $$
#
# ---
#
# ### c. Quantile Baseline
# Always predicts a specified quantile $q$ of the targets:
#
# $$
# \hat{y} = Q_q(y)
# $$
#
# ---
#
# ### d. Evaluation Metrics (Regression)
#
# - **Mean Squared Error (MSE)**
#
# $$
# MSE = \frac{1}{N} \sum_{i=1}^N (y_i - \hat{y}_i)^2
# $$
#
# - **Root Mean Squared Error (RMSE)**
#
# $$
# RMSE = \sqrt{MSE}
# $$
#
# - **Mean Absolute Error (MAE)**
#
# $$
# MAE = \frac{1}{N} \sum_{i=1}^N |y_i - \hat{y}_i|
# $$
#
# - **Coefficient of Determination ($R^2$)**
#
# $$
# R^2 = 1 - \frac{\sum_{i=1}^N (y_i - \hat{y}_i)^2}{\sum_{i=1}^N (y_i - \bar{y})^2}
# $$
#
# Where:
# - $y_i$: true values
# - $\hat{y}_i$: predicted values
# - $\bar{y}$: mean of true values
#
# ---
#
# ## 3. Statistical Justification
#
# Dummy estimators formalize the **null hypothesis**: predictions contain **no learning signal**.
#
# - **Classification baselines**: majority class prediction or random guessing.
# - **Regression baselines**: mean or median constant predictions.
#
# ➡️ Any valid model must achieve performance **significantly better than these baselines** to demonstrate **true predictive learning**.

# %% [markdown]
# # 📚 Academic Works Supporting Dummy Estimators & Baseline Evaluation
#
# ---
#
# ## 🔹 Foundational Concepts of Baseline Models
#
# - **Wolpert, D. H. (1996).** *The Lack of A Priori Distinctions Between Learning Algorithms.* Neural Computation.
#   ➝ Introduces the **“no free lunch” theorem**, highlighting why baseline models (dummy/random) are crucial for **fair benchmarking**.
#
# - **Breiman, L. (2001).** *Statistical Modeling: The Two Cultures.* Statistical Science.
#   ➝ Advocates for evaluating machine learning models against **simple statistical baselines** before claiming improvements.
#
# - **Dietterich, T. G. (1998).** *Approximate Statistical Tests for Comparing Supervised Classification Learning Algorithms.* Neural Computation.
#   ➝ Formalizes the use of **baseline learners in hypothesis testing** and comparison of classifiers.
#
# ---
#
# ## 🔹 Classification Metrics & Baselines
#
# - **Powers, D. M. W. (2011).** *Evaluation: From Precision, Recall and F-Score to ROC, Informedness, Markedness & Correlation.* Journal of Machine Learning Technologies.
#   ➝ Standard reference for **accuracy, precision, recall, F1, ROC AUC**, all metrics used to benchmark against dummy classifiers.
#
# - **Provost, F., & Fawcett, T. (2001).** *Robust Classification for Imprecise Environments.* Machine Learning.
#   ➝ Shows how **ROC curves and random baselines** are critical for validating classifier performance.
#
# - **Ferri, C., Hernández-Orallo, J., & Modroiu, R. (2009).** *An Experimental Comparison of Performance Measures for Classification.* Pattern Recognition Letters.
#   ➝ Provides an extensive **comparison of metrics**, reinforcing why dummy classifiers provide **lower-bound benchmarks**.
#
# ---
#
# ## 🔹 Regression Baselines & Metrics
#
# - **Draper, N. R., & Smith, H. (1998).** *Applied Regression Analysis.* Wiley.
#   ➝ Classic reference on **regression diagnostics**, formalizing MSE, RMSE, $R^2$, and **mean/median baseline predictors**.
#
# - **Chicco, D., & Jurman, G. (2020).** *The Advantages of the Matthews Correlation Coefficient (MCC) over F1 Score and Accuracy in Binary Classification Evaluation.* BMC Genomics.
#   ➝ Demonstrates pitfalls of using **accuracy alone** and emphasizes **baseline comparators** in regression and classification.
#
# - **Hastie, T., Tibshirani, R., & Friedman, J. (2009).** *The Elements of Statistical Learning.* Springer.
#   ➝ Canonical text on supervised learning; presents **null models** (mean/median predictors) as regression baselines.
#
# ---
#
# ## 🔹 Practical Implementations
#
# - **Pedregosa, F., et al. (2011).** *Scikit-learn: Machine Learning in Python.* Journal of Machine Learning Research.
#   ➝ Introduces **DummyClassifier** and **DummyRegressor** implementations, now standard baselines in practice.
#
# - **Guyon, I., & Elisseeff, A. (2003).** *An Introduction to Variable and Feature Selection.* Journal of Machine Learning Research.
#   ➝ Suggests testing **dummy/random predictors** before performing **feature selection** to ensure added value.
#
# - **Drummond, C., & Holte, R. C. (2006).** *Cost Curves: An Improved Method for Visualizing Classifier Performance.* Machine Learning.
#   ➝ Provides visualization techniques (**cost curves, ROC curves**) showing where **dummy classifiers define the minimum performance floor**.
#
# ---
#
# ## ✅ Academic Justification
#
# Together, these works establish dummy estimators as **statistically grounded null models**:
#
# - They act as the **minimum performance benchmark**.
# - They ensure **empirical validation** by requiring real models to beat trivial baselines.
# - They connect theory (**no free lunch, risk minimization**) with practice (**scikit-learn Dummy estimators, ROC/Cost curves**).

# %%
# =====================================================
# Project: Baseline Evaluation with Dummy Estimators
# =====================================================

# ---- Import Libraries ----
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer, load_diabetes
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, r2_score, mean_squared_error

# =====================================================
# 1. Classification: Breast Cancer Dataset
# =====================================================
X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Dummy Classifiers
dummy_stratified = DummyClassifier(strategy="stratified", random_state=42)
dummy_mostfreq = DummyClassifier(strategy="most_frequent")

# Real Classifier
clf = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(max_iter=500))
])

# Fit and evaluate
models = {
    "Dummy (Most Frequent)": dummy_mostfreq,
    "Dummy (Stratified)": dummy_stratified,
    "Logistic Regression": clf
}

results_clf = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    if name == "Logistic Regression":
        y_proba = model.predict_proba(X_test)[:,1]
        auc = roc_auc_score(y_test, y_proba)
    else:
        auc = np.nan
    results_clf[name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "F1": f1_score(y_test, y_pred),
        "ROC AUC": auc
    }

df_clf = pd.DataFrame(results_clf).T
print("=== Classification Results ===")
print(df_clf)
# Out:
# === Classification Results ===
#                        Accuracy        F1   ROC AUC
# Dummy (Most Frequent)  0.625731  0.769784       NaN
# Dummy (Stratified)     0.514620  0.621005       NaN
# Logistic Regression    0.988304  0.990654  0.998102

# %%
# Visualize
df_clf.plot(kind="bar", figsize=(8,5))
plt.title("Classification: Dummy vs Real Model")
plt.ylabel("Score")
plt.xticks(rotation=30)
plt.show()

# %%
# =====================================================
# 2. Regression: Diabetes Dataset
# =====================================================
X, y = load_diabetes(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Dummy Regressors
dummy_mean = DummyRegressor(strategy="mean")
dummy_median = DummyRegressor(strategy="median")

# %%
# Real Regressor
reg = Pipeline([
    ('scaler', StandardScaler()),
    ('reg', LinearRegression())
])

# Fit and evaluate
models_reg = {
    "Dummy (Mean)": dummy_mean,
    "Dummy (Median)": dummy_median,
    "Linear Regression": reg
}

results_reg = {}
for name, model in models_reg.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    results_reg[name] = {
        "MSE": mean_squared_error(y_test, y_pred),
        "R2": r2_score(y_test, y_pred)
    }

df_reg = pd.DataFrame(results_reg).T
print("\n=== Regression Results ===")
print(df_reg)
# Out:
# === Regression Results ===
#                            MSE        R2
# Dummy (Mean)       5432.886351 -0.006405
# Dummy (Median)     5434.578947 -0.006719
# Linear Regression  2821.750981  0.477290

# %%
# Visualize
fig, axes = plt.subplots(1, 2, figsize=(12,5))
sns.barplot(data=df_reg.reset_index(), x="index", y="MSE", ax=axes[0], palette="coolwarm")
axes[0].set_title("Regression: MSE Comparison")
axes[0].set_ylabel("MSE"); axes[0].set_xlabel("Model")
axes[0].set_xticklabels(df_reg.index, rotation=30)

sns.barplot(data=df_reg.reset_index(), x="index", y="R2", ax=axes[1], palette="viridis")
axes[1].set_title("Regression: R² Comparison")
axes[1].set_ylabel("R²"); axes[1].set_xlabel("Model")
axes[1].set_xticklabels(df_reg.index, rotation=30)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2222126045.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_reg.reset_index(), x="index", y="MSE", ax=axes[0], palette="coolwarm")
# /tmp/ipython-input-2222126045.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(df_reg.index, rotation=30)
# /tmp/ipython-input-2222126045.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_reg.reset_index(), x="index", y="R2", ax=axes[1], palette="viridis")
# ...

# %% [markdown]
# # 📖 Academic Explanation of Results: Dummy vs Real Models
#
# ---
#
# ## 🔹 1. Classification (Breast Cancer Dataset)
#
# ### Dummy Classifiers (Most Frequent / Stratified)
#
# - **Accuracy:** ~0.51–0.62
# - **F1-scores:** Low
# - **ROC AUC:** Not meaningful
#
# ➡️ **Interpretation:**
# Dummy classifiers do **not learn patterns**, instead relying on trivial baselines (e.g., predicting the majority class or random sampling).
#
# ---
#
# ### Logistic Regression (Real Model)
#
# - **Accuracy:** ~0.99
# - **F1-score:** ~0.99
# - **ROC AUC:** ~0.998
#
# ➡️ **Interpretation:**
# The large improvement demonstrates that logistic regression extracts **discriminative structure** from features.
# This is critical in **medical diagnostic contexts**, where both precision and recall are vital.
#
# ---
#
# ### Academic Insight
#
# - Dummy classifiers establish the **baseline threshold of “no learning.”**
# - The stark performance gap validates the **added predictive value** of trained models.
#
# ---
#
# ## 🔹 2. Regression (Diabetes Dataset)
#
# ### Dummy Regressors (Mean / Median)
#
# - **MSE:** ~5433
# - **$R^2$:** ≈ 0.0
#
# ➡️ **Interpretation:**
# Explains **almost no variance** — equivalent to naive constant predictions.
#
# ---
#
# ### Linear Regression (Real Model)
#
# - **MSE:** ~2821
# - **RMSE:** ~53.1
# - **$R^2$:** ≈ 0.48
#
# ➡️ **Interpretation:**
# Linear regression captures **~48% of variance**, showing meaningful predictive ability but also highlighting dataset complexity (nonlinear effects unexplained).
#
# ---
#
# ### Academic Insight
#
# - Dummy regressors = **yardstick**.
# - If a real model does not beat this baseline → possible **underfitting** or **poor feature design**.
# - Linear regression surpasses baseline but also signals need for **nonlinear or regularized models**.
#
# ---
#
# ## 🔹 3. Visual Diagnostics
#
# - **Classification Bar Plots** → Show wide margin between dummy and logistic regression.
#   - Communicates effectively that ML **outperforms chance**.
#
# - **Regression Bar Plots** → Clear gap in MSE and $R^2$ between dummy and linear regression.
#   - Graphical comparison enhances **interpretability** for academic and applied audiences.
#
# ---
#
# ## 🎓 Academic Justification
#
# ### Theoretical Rationale
# - Dummy models represent the **null hypothesis**: no learnable structure in data.
# - Comparing real vs dummy models tests whether predictive signal is **genuine or spurious**.
#
# ### Empirical Validation
# - Superiority of logistic and linear regression over dummy baselines confirms the **predictive relevance** of features.
#
# ### Broader Implications
# - Aligns with **best practices in statistical learning**.
# - Prevents misleading claims of improvement driven by data imbalance or random variation.
#
# ---
#
# ## ✅ Verdict
#
# - **Classification** → Logistic regression far outperforms dummy baselines, validating clinical applicability.
# - **Regression** → Linear regression beats naive baselines but highlights the need for more expressive models.
#
# ➡️ Dummy vs real model comparison ensures that **machine learning adds true predictive value** beyond naive heuristics.

# %% [markdown]
# # 📖 Academic Explanation
#
# ---
#
# ## 🔹 Abstract
# Exhaustive grid search is a **hyperparameter optimization strategy** in which a predefined set of hyperparameter values is systematically explored. Each combination of hyperparameters is evaluated using **cross-validation**, and the configuration yielding the highest validation performance is selected.
#
# This procedure guarantees that the optimal parameters within the given search space are identified, albeit at a potentially **high computational cost**.
#
# ---
#
# ## 🔹 Methodology
#
# Let an estimator $f(x;\theta)$ depend on hyperparameters $\theta \in \Theta$.
# In exhaustive grid search, we define a **discrete parameter grid**:
#
# $$
# \Theta = \{\theta_1, \theta_2, \dots, \theta_m\}
# $$
#
# For each candidate $\theta_j$, the estimator is trained and evaluated via **$K$-fold cross-validation**.
# The mean validation score is:
#
# $$
# CV(\theta_j) = \frac{1}{K} \sum_{k=1}^K M_k(\theta_j)
# $$
#
# where $M_k(\theta_j)$ is the performance metric on fold $k$.
#
# The optimal parameters are chosen as:
#
# $$
# \theta^\ast = \arg\max_{\theta_j \in \Theta} \, CV(\theta_j)
# $$
#
# ---
#
# ## 🔹 Results & Discussion
#
# **Advantages:**
# - ✅ Guarantees finding the best-performing hyperparameters within the defined grid.
# - ✅ Simple and parallelizable.
#
# **Limitations:**
# - ⚠️ Computationally expensive, especially with large grids and high-dimensional parameter spaces.
# - ⚠️ Sensitive to grid resolution:
#   - A **coarse grid** may miss optimal values.
#   - A **fine grid** may become infeasible.
#
# ---
#
# ## 🔹 Conclusion
#
# Exhaustive grid search provides a **rigorous and deterministic framework** for hyperparameter optimization.
#
# Although **computationally demanding**, it remains a **widely used baseline method** due to its:
# - Simplicity
# - Reproducibility
# - Ability to ensure discovery of the best configuration within a predefined search space.

# %% [markdown]
# # 📐 Mathematical & Statistical Equations in Hyperparameter Tuning and Grid Search
#
# ---
#
# ## 1. Model Definition (Estimator)
#
# A machine learning model is parameterized by **weights** $w$ and **hyperparameters** $\theta$:
#
# $$
# f(x; w, \theta) \; \to \; \hat{y}
# $$
#
# - $w$: learned parameters (e.g., regression coefficients).
# - $\theta$: hyperparameters (e.g., regularization constant $C$, kernel parameter $\gamma$).
# - $\hat{y}$: model prediction.
#
# ---
#
# ## 2. Loss Functions (Objective to Minimize)
#
# **Logistic Regression (Cross-Entropy Loss):**
#
# $$
# J(w,b;\theta) = -\frac{1}{N} \sum_{i=1}^N \Big[ y^{(i)} \log \hat{y}^{(i)} + (1 - y^{(i)}) \log \big(1 - \hat{y}^{(i)}\big) \Big]
# $$
#
# With **L2 regularization** (hyperparameter $C$):
#
# $$
# J_{\text{reg}}(w,b;C) = J(w,b) + \frac{1}{2C} \, \|w\|^2_2
# $$
#
# ---
#
# ## 3. Performance Metrics (Evaluation Functions)
#
# - **Accuracy (Classification):**
#
# $$
# \text{Accuracy} = \frac{1}{N} \sum_{i=1}^N \mathbf{1}\big(\hat{y}^{(i)} = y^{(i)}\big)
# $$
#
# - **Mean Squared Error (Regression):**
#
# $$
# MSE = \frac{1}{N} \sum_{i=1}^N \big(y^{(i)} - \hat{y}^{(i)}\big)^2
# $$
#
# - **F1 Score (Harmonic Mean of Precision & Recall):**
#
# $$
# F_1 = \frac{2 \cdot \text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}
# $$
#
# ---
#
# ## 4. Cross-Validation Estimation
#
# Given dataset $D = \{(x_i, y_i)\}_{i=1}^N$ split into $K$ folds, performance for hyperparameters $\theta$:
#
# $$
# CV(\theta) = \frac{1}{K} \sum_{k=1}^K M_k(\theta)
# $$
#
# - $M_k(\theta)$: metric score on fold $k$.
# - $CV(\theta)$: average validation performance.
#
# ---
#
# ## 5. Grid Search Optimization
#
# Given hyperparameter search space $\Theta$:
#
# $$
# \theta^\ast = \arg\max_{\theta \in \Theta} \; CV(\theta)
# $$
#
# where $\theta^\ast$ is the best-performing hyperparameter set under cross-validation.
#
# ---
#
# ## 6. Bias–Variance Tradeoff
#
# The expected prediction error decomposes into bias, variance, and noise:
#
# $$
# \mathbb{E}[(y - \hat{f}(x))^2] =
# \underbrace{\big(\mathbb{E}[\hat{f}(x)] - f(x)\big)^2}_{\text{Bias}^2} +
# \underbrace{\mathbb{E}\big[(\hat{f}(x) - \mathbb{E}[\hat{f}(x)])^2\big]}_{\text{Variance}} +
# \sigma^2
# $$
#
# ---
#
# ## 7. Statistical Significance of Model Selection
#
# Permutation test $p$-value:
#
# $$
# p = \frac{1 + \sum_{j=1}^n \mathbf{1}(CV^{\pi_j} \geq CV)}{n+1}
# $$
#
# - $CV$: observed cross-validation score.
# - $CV^{\pi_j}$: score with permuted labels.
# - $n$: number of permutations.
#
# ---
#
# ## 8. Generalization Error Bound (VC Dimension Approximation)
#
# With probability $1 - \delta$:
#
# $$
# R(f) \leq \hat{R}(f) + \sqrt{\frac{h \big(\log \frac{2N}{h} + 1\big) - \log \frac{\delta}{4}}{N}}
# $$
#
# - $R(f)$: true risk.
# - $\hat{R}(f)$: empirical risk.
# - $h$: VC dimension of the hypothesis class.
# - $N$: number of training samples.
#
# ---
#
# # ✅ Summary
#
# This field combines:
# - **Optimization equations** (grid search objective, loss functions).
# - **Statistical metrics** (accuracy, F1, MSE).
# - **Validation equations** (cross-validation average, bias–variance tradeoff).
# - **Statistical inference** (permutation tests, generalization bounds).
#
# Together, they form the **mathematical foundation of model selection and hyperparameter tuning** in machine learning.

# %% [markdown]
# # 📚 Key Academic Milestones in Cross-Validation, Model Selection, and Statistical Testing
#
# ---
#
# ## 🏛 Foundations of Cross-Validation
# - **Stone, 1974.** *Cross-validation formalization and use for prediction/selection.*
#   🔗 [rss.onlinelibrary.wiley.com](https://rss.onlinelibrary.wiley.com)
#
# - **Geisser, 1975.** *Predictive sample reuse (early CV).*
#   🔗 [jstor.org](https://www.jstor.org)
#
# ---
#
# ## 📖 Influential Empirical & Survey Papers
# - **Kohavi, 1995.** *Comparative study of CV vs. bootstrap; guidance on folds and model selection.*
#   🔗 [ijcai.org](https://www.ijcai.org)
#
# - **Arlot & Celisse, 2010.** *Survey of CV procedures for model selection (theory + practice).*
#   🔗 [projecteuclid.org](https://projecteuclid.org)
#
# ---
#
# ## ⚠️ Bias, Nested CV, and Selection Pitfalls
# - **Varma & Simon, 2006.** *Bias when tuning and evaluating on the same CV; motivates nested CV.*
#   🔗 [biomedcentral.com](https://www.biomedcentral.com)
#
# - **Cawley & Talbot, 2010.** *Overfitting the model-selection criterion; remedies and best practices.*
#   🔗 [jmlr.org](https://jmlr.org)
#
# ---
#
# ## 🎛 Hyperparameter Optimization
# - **Bergstra & Bengio, 2012.** *Random search often superior to grid search in high-dimensional spaces.*
#   🔗 [jmlr.org](https://jmlr.org)
#
# ---
#
# ## 🧪 Significance Tests & Permutation Testing
# - **Ojala & Garriga, 2010.** *Permutation tests for classifier performance; basis for Scikit-learn’s `permutation_test_score`.*
#   🔗 [jmlr.org](https://jmlr.org)
#
# ---
#
# ## ⚖️ Comparing Learners: Statistical Testing on CV Results
# - **Dietterich, 1998.** *Approximate statistical tests (e.g., 5×2cv t-test) for comparing algorithms.*
#   🔗 [sci2s.ugr.es](https://sci2s.ugr.es)
#
# - **Nadeau & Bengio, 2003.** *Variance of CV estimators; corrected tests for generalization error comparisons.*
#   🔗 [link.springer.com](https://link.springer.com)
#
# - **Markatou et al., 2005.** *Variance analysis of CV estimators; methodological refinements.*
#   🔗 [jmlr.org](https://jmlr.org)

# %%
# End-to-End ML Project: Exhaustive Grid Search (Scikit-learn)

### Import libraries politely
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

### Load dataset politely (Digits dataset for classification)
digits = load_digits()
X, y = digits.data, digits.target

### Split into training and test sets politely
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

### Define pipeline politely (Scaler + SVM classifier)
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", SVC())
])

### Define parameter grid politely for exhaustive search
param_grid = {
    "clf__C": [0.1, 1, 10],
    "clf__gamma": [1, 0.1, 0.01],
    "clf__kernel": ["rbf", "linear"]
}

### Perform exhaustive grid search politely with cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=cv,
    scoring="accuracy",
    n_jobs=-1
)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('clf', SVC())]),
#              n_jobs=-1,
#              param_grid={'clf__C': [0.1, 1, 10], 'clf__gamma': [1, 0.1, 0.01],
#                          'clf__kernel': ['rbf', 'linear']},
#              scoring='accuracy')

# %%
### Print best parameters and CV score politely
print("Best Parameters:", grid.best_params_)
print("Best CV Accuracy:", grid.best_score_)
# Out:
# Best Parameters: {'clf__C': 0.1, 'clf__gamma': 1, 'clf__kernel': 'linear'}
# Best CV Accuracy: 0.9798175571041424

# %%
### Evaluate best model on test data politely
y_pred = grid.best_estimator_.predict(X_test)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.94      0.94      0.94        36
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        37
#            4       0.97      1.00      0.99        36
#            5       1.00      1.00      1.00        37
#            6       1.00      1.00      1.00        36
#            7       0.95      1.00      0.97        36
#            8       0.97      0.91      0.94        35
#            9       1.00      0.97      0.99        36
#
#     accuracy                           0.98       360
#    macro avg       0.98      0.98      0.98       360
# weighted avg       0.98      0.98      0.98       360

# %%
### Confusion matrix politely
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=digits.target_names,
            yticklabels=digits.target_names)
plt.title("Confusion Matrix (Best Grid Search Model)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %% [markdown]
# # 📖 Academic Results Interpretation
#
# ---
#
# ## 🔹 Best Hyperparameters and Cross-Validation Performance
#
# The exhaustive grid search identified the optimal parameter configuration for the **Support Vector Machine (SVM):**
#
# $$
# \theta^\ast = \{ C = 0.1, \; \gamma = 1, \; \text{kernel} = \text{linear} \}
# $$
#
# This configuration yielded a **5-fold cross-validated accuracy** of:
#
# $$
# CV_5(\theta^\ast) \approx 0.98
# $$
#
# ➡️ Demonstrates high model **stability** and **generalization ability** during training.
#
# ---
#
# ## 🔹 Test Set Evaluation
#
# The tuned model was evaluated on the **unseen test set**. Key performance metrics:
#
# - **Overall Accuracy**: $0.98$
# - **Macro-average F1-score**: $0.98$
# - **Weighted-average F1-score**: $0.98$
#
# ✅ Indicates balanced performance across all classes, with minimal variation between **precision** and **recall**.
#
# ---
#
# ## 🔹 Per-Class Performance (Classification Report)
#
# - Most classes achieved **perfect scores (1.00)** in precision, recall, and F1.
# - A few classes (e.g., class **1, 7, 8**) showed slightly reduced recall ($0.91$–$0.94$), reflecting **minor misclassifications**.
# - Macro-level balance confirms **robust multi-class discrimination**.
#
# ---
#
# ## 🔹 Confusion Matrix Analysis
#
# The confusion matrix visualization confirms:
#
# - **Diagonal dominance** → Nearly all samples correctly classified.
# - **Sparse off-diagonal entries** → Very few misclassifications (e.g., class *8* confused with *1* and *7*).
# - **Consistency across classes** → Each digit/class exhibits recognition accuracy $\geq 91\%$.
#
# ---
#
# ## 🔹 Conclusion
#
# The exhaustive grid search successfully optimized the SVM hyperparameters, resulting in a classifier that:
#
# - Achieves **very high predictive accuracy (98%)** on unseen data.
# - Maintains **balanced performance across all classes**, as evidenced by macro- and weighted-average F1 metrics.
# - Exhibits **minimal misclassification**, validated by the nearly perfect confusion matrix.
#
# 📌 This validates **exhaustive grid search** as a rigorous framework for hyperparameter optimization, ensuring **robust generalization** in multi-class classification tasks.

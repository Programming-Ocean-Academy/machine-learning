# %% [markdown]
# # 📖 3.4.2. Scoring API Overview – Academic Explanation
#
# ---
#
# ## 1. Conceptual Foundation
#
# In **supervised learning**, the quality of predictions must be assessed relative to the true outcomes.
#
# - The **Scoring API** in `scikit-learn` formalizes this by mapping predictions $\hat{y}$ (or probability estimates $\hat{p}$) to a **scalar score** representing model performance.
# - Scores can be **maximized** (e.g., accuracy, F1, ROC–AUC) or **minimized** (e.g., mean squared error).
# - To maintain consistency, the API applies a **maximization convention**:
#   - Higher is always better.
#   - Negative signs are applied internally for error functions such as MSE.
#
# ---
#
# ## 2. Mechanics of the API
#
# Models can be evaluated via functions such as:
#
# - `cross_val_score`
# - `cross_validate`
# - `GridSearchCV`
# - `RandomizedSearchCV`
#
# The **scoring parameter** accepts:
#
# 1. **Predefined metric names** (e.g., `"accuracy"`, `"f1"`, `"roc_auc"`, `"neg_mean_squared_error"`).
# 2. **Custom callables**, enabling domain-specific evaluation criteria.
# 3. **Dictionaries of multiple metrics**, allowing simultaneous evaluation across dimensions.
#
# 👉 This **modular design** ensures **reproducibility** and **comparability** across experiments.
#
# ---
#
# ## 3. Mathematical Formalization
#
# For a general prediction task, a scoring function can be represented as:
#
# $$
# s = S(y, \hat{y})
# $$
#
# where:
# - $y$ = ground truth labels or responses
# - $\hat{y}$ = predicted labels or estimated values
# - $S(\cdot)$ = scoring function mapping $(y, \hat{y}) \to \mathbb{R}$
#
# ### Examples
#
# - **Classification Accuracy**
#
# $$
# S(y, \hat{y}) = \frac{1}{n} \sum_{i=1}^n \mathbf{1}(y_i = \hat{y}_i)
# $$
#
# - **Mean Squared Error (MSE)**
#
# $$
# S(y, \hat{y}) = -\frac{1}{n} \sum_{i=1}^n (y_i - \hat{y}_i)^2
# $$
#
# (Negative sign ensures maximization convention in `scikit-learn`.)
#
# - **ROC AUC**
#
# $$
# S(y, \hat{p}) = \int_0^1 TPR(FPR^{-1}(t)) \, dt
# $$
#
# ---
#
# ## 4. Academic Significance
#
# - The Scoring API encapsulates **best practices** in model evaluation, ensuring metrics are applied **consistently** across tasks.
# - It promotes **comparative research**, enabling algorithms and hyperparameters to be benchmarked under identical scoring schemes.
# - Its **extensibility via custom scorers** aligns with **domain adaptation principles**, where evaluation criteria differ between fields (e.g., medicine vs finance).
#
# ---
#
# ## ✅ Summary
#
# The **Scoring API in scikit-learn** provides a **methodologically rigorous interface** for evaluation:
#
# - Abstracts metrics into a **flexible, reproducible, and standardized framework**.
# - Unifies disparate metrics under a **maximization convention**.
# - Enables **multi-metric evaluation**, advancing both **theoretical clarity** and **practical applicability** in machine learning research.

# %% [markdown]
# # 📊 Unified Mathematical Framework of Scoring Functions
#
# | **Metric** | **Equation** | **Type** | **Interpretation** |
# |------------|--------------|----------|--------------------|
# | **Accuracy** | $$ \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN} $$ | Classification | Fraction of correct predictions over total cases. |
# | **Precision** | $$ \text{Precision} = \frac{TP}{TP + FP} $$ | Classification | Proportion of predicted positives that are true positives. |
# | **Recall (Sensitivity, TPR)** | $$ \text{Recall} = \frac{TP}{TP + FN} $$ | Classification | Fraction of actual positives correctly identified. |
# | **Specificity (TNR)** | $$ \text{Specificity} = \frac{TN}{TN + FP} $$ | Classification | Fraction of actual negatives correctly identified. |
# | **F1 Score** | $$ F_1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}} $$ | Classification | Harmonic mean of precision and recall. |
# | **ROC AUC** | $$ AUC = \int_0^1 TPR(FPR^{-1}(t)) \, dt $$ | Classification | Probability that classifier ranks a random positive higher than a random negative. |
# | **Log Loss (Cross-Entropy)** | $$ \text{LogLoss} = -\frac{1}{n} \sum_{i=1}^n \big[ y_i \log(\hat{p}_i) + (1-y_i)\log(1-\hat{p}_i) \big] $$ | Classification | Penalizes probabilistic predictions far from the true label. |
# | **Mean Squared Error (MSE)** | $$ MSE = \frac{1}{n} \sum_{i=1}^n (y_i - \hat{y}_i)^2 $$ | Regression | Average squared deviation between true and predicted values. |
# | **Root Mean Squared Error (RMSE)** | $$ RMSE = \sqrt{MSE} $$ | Regression | Standard deviation of prediction errors. |
# | **Mean Absolute Error (MAE)** | $$ MAE = \frac{1}{n} \sum_{i=1}^n |y_i - \hat{y}_i| $$ | Regression | Average absolute deviation, robust to outliers. |
# | **$R^2$ (Coefficient of Determination)** | $$ R^2 = 1 - \frac{\sum_{i=1}^n (y_i - \hat{y}_i)^2}{\sum_{i=1}^n (y_i - \bar{y})^2} $$ | Regression | Proportion of variance in $y$ explained by the model. |
# | **Explained Variance (EVS)** | $$ EVS = 1 - \frac{\text{Var}(y - \hat{y})}{\text{Var}(y)} $$ | Regression | Measures how much of the variance is captured by predictions. |
#
# ---
#
# ## ✅ Notes
#
# - $TP, TN, FP, FN$ = True Positives, True Negatives, False Positives, False Negatives.
# - $y_i$ = true value; $\hat{y}_i$ = predicted value; $\hat{p}_i$ = predicted probability; $\bar{y}$ = mean of $y$.
# - `scikit-learn` follows a **maximization convention**, so metrics like MSE are internally negated (`neg_mean_squared_error`).
#
# 📖 This table serves as a **self-contained academic reference** for *3.4.2 Scoring API Overview*, connecting **implementation (scikit-learn)** with **theoretical equations** from statistics & ML theory.

# %% [markdown]
# # 📚 Academic References Supporting the Lab
#
# ---
#
# ## 1. Foundations of Model Evaluation
#
# - **Stone, M. (1974).** Cross-Validatory Choice and Assessment of Statistical Predictions.
#   *Journal of the Royal Statistical Society, Series B.*
#   🔹 One of the earliest formalizations of **cross-validation** in statistical learning.
#
# - **Kohavi, R. (1995).** A Study of Cross-Validation and Bootstrap for Accuracy Estimation and Model Selection.
#   *Proceedings of IJCAI.*
#   🔹 Classic paper showing why **cross-validation** provides more reliable estimates of model performance than a single split.
#
# ---
#
# ## 2. Classification Metrics
#
# - **Hanley, J. A., & McNeil, B. J. (1982).** The Meaning and Use of the Area under a Receiver Operating Characteristic (ROC) Curve.
#   *Radiology, 143(1), 29–36.*
#   🔹 Defined **AUC** as a probabilistic interpretation of classifier performance.
#
# - **Swets, J. A. (1988).** Measuring the Accuracy of Diagnostic Systems.
#   *Science, 240(4857), 1285–1293.*
#   🔹 Introduced **ROC analysis** to evaluate diagnostic classifiers.
#
# - **van Rijsbergen, C. J. (1979).** *Information Retrieval.* Butterworths.
#   🔹 First formalization of the **F-measure (F1-score)** as the harmonic mean of precision and recall.
#
# - **He, H., & Garcia, E. A. (2009).** Learning from Imbalanced Data.
#   *IEEE Transactions on Knowledge and Data Engineering.*
#   🔹 Explains why **accuracy can be misleading** in imbalanced datasets and advocates for **F1, ROC–AUC, and PR curves**.
#
# ---
#
# ## 3. Regression Metrics
#
# - **Draper, N. R., & Smith, H. (1998).** *Applied Regression Analysis (3rd ed.).* Wiley.
#   🔹 Canonical reference for regression diagnostics (**MSE, MAE, $R^2$, residual analysis**).
#
# - **Hastie, T., Tibshirani, R., & Friedman, J. (2009).** *The Elements of Statistical Learning.* Springer.
#   🔹 Provides theoretical grounding of **regression evaluation**, bias–variance trade-offs, and diagnostics.
#
# - **Chicco, D., & Jurman, G. (2020).** The Advantages of the Matthews Correlation Coefficient (MCC) over F1 Score and Accuracy in Binary Classification Evaluation.
#   *BMC Genomics.*
#   🔹 Expands discussion on **robustness of evaluation metrics**, especially in **medical/bioinformatics contexts**.
#
# ---
#
# ## 4. Probabilistic Scoring & Calibration
#
# - **Good, I. J. (1952).** Rational Decisions.
#   *Journal of the Royal Statistical Society.*
#   🔹 Early foundation of **probability scoring rules**, leading to modern **log-loss**.
#
# - **Gneiting, T., & Raftery, A. E. (2007).** Strictly Proper Scoring Rules, Prediction, and Estimation.
#   *Journal of the American Statistical Association, 102(477), 359–378.*
#   🔹 Defines **log-loss** and **Brier score** as **proper scoring rules** for probabilistic predictions.
#
# ---
#
# ## 5. Machine Learning Practice
#
# - **Domingos, P. (2012).** A Few Useful Things to Know About Machine Learning.
#   *Communications of the ACM, 55(10), 78–87.*
#   🔹 Explains common pitfalls in model evaluation and importance of aligning **metrics with task goals**.
#
# - **Goodfellow, I., Bengio, Y., & Courville, A. (2016).** *Deep Learning.* MIT Press.
#   🔹 Chapters on **evaluation metrics, generalization, and regularization** provide context for scoring in modern ML systems.
#
# ---
#
# ## ✅ Academic Justification
#
# This lab is strongly aligned with **statistical learning theory** and **applied ML best practices**:
#
# - **Cross-validation** → Grounded in *Stone (1974)* and *Kohavi (1995)*.
# - **Classification metrics** → Supported by *Swets (1988)*, *Hanley & McNeil (1982)*, *van Rijsbergen (1979)*.
# - **Regression metrics** → Anchored in *Draper & Smith (1998)*, *Hastie et al. (2009)*.
# - **Probabilistic scoring** → Formalized in *Good (1952)* and *Gneiting & Raftery (2007)*.
# - **ML practice** → Contextualized by *Domingos (2012)* and *Goodfellow et al. (2016)*.

# %%
# =====================================================
# Project: Unified Evaluation with Scikit-learn Scoring API
# =====================================================

# ---- Import Libraries ----
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer, load_diabetes
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import (
    confusion_matrix, classification_report, roc_curve, auc, precision_recall_curve,
    mean_squared_error, mean_absolute_error, r2_score
)

# %%
# =====================================================
# 1. Classification: Breast Cancer Dataset
# =====================================================
data = load_breast_cancer()
X, y = data.data, data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

clf_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(max_iter=500))
])
clf_pipe.fit(X_train, y_train)
y_pred = clf_pipe.predict(X_test)
y_proba = clf_pipe.predict_proba(X_test)[:, 1]

print("=== Classification Report ===")
print(classification_report(y_test, y_pred, target_names=data.target_names))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#    malignant       0.98      0.98      0.98        64
#       benign       0.99      0.99      0.99       107
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %%
# Visual 1: Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=data.target_names, yticklabels=data.target_names)
plt.title("Confusion Matrix (Classification)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Visual 2: ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
# Visual 3: Precision-Recall Curve
prec, rec, _ = precision_recall_curve(y_test, y_proba)
plt.plot(rec, prec, label="PR Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

# %%
# =====================================================
# 2. Regression: Diabetes Dataset
# =====================================================
reg_data = load_diabetes()
X, y = reg_data.data, reg_data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

reg_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('reg', LinearRegression())
])
reg_pipe.fit(X_train, y_train)
y_pred = reg_pipe.predict(X_test)

print("\n=== Regression Metrics ===")
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# === Regression Metrics ===
# MSE: 2821.750981001311
# RMSE: 53.120156070942706
# MAE: 41.91937845679274
# R2 Score: 0.4772897164322617

# %%
# Visual 4: Residual Plot
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("Residual Plot (Regression)")
plt.show()

# %%
# Visual 5: Distribution of Residuals
residuals = y_test - y_pred
sns.histplot(residuals, kde=True, color="red")
plt.title("Distribution of Residuals")
plt.xlabel("Error")
plt.show()

# %%
# =====================================================
# 3. Cross-validation with Multiple Scoring Functions
# =====================================================
scoring = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
cv_results = cross_validate(clf_pipe, data.data, data.target, cv=5, scoring=scoring, return_train_score=False)
cv_df = pd.DataFrame(cv_results)

print("\n=== Cross-validation Scores (5-Fold) ===")
print(cv_df.mean())
# Out:
# === Cross-validation Scores (5-Fold) ===
# fit_time          0.097914
# score_time        0.031250
# test_accuracy     0.980686
# test_precision    0.978224
# test_recall       0.991588
# test_f1           0.984767
# test_roc_auc      0.995187
# dtype: float64

# %%
# Visual 6: Barplot of CV Scores
cv_means = cv_df[[f'test_{s}' for s in scoring]].mean()
sns.barplot(x=cv_means.index, y=cv_means.values, palette="viridis")
plt.ylabel("Mean CV Score")
plt.title("Cross-Validation Performance Across Metrics")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-1446563786.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cv_means.index, y=cv_means.values, palette="viridis")

# %% [markdown]
# # 📊 Academic Explanation of Visuals in the Unified Lab
#
# ---
#
# ## 1. Confusion Matrix (Classification)
#
# - **What it shows:** Distribution of true vs. predicted labels for the breast cancer dataset.
# - **Interpretation:** Almost all samples fall along the diagonal (correct predictions), with only 1–2 misclassifications.
# - **Academic Justification:** Provides **granular error analysis**, distinguishing between **false positives** (benign misclassified as malignant) and **false negatives** (malignant missed). Crucial in **medical diagnostics**, where different errors have **asymmetric costs**.
#
# ---
#
# ## 2. ROC Curve (Classification)
#
# - **What it shows:** Trade-off between **True Positive Rate (Recall)** and **False Positive Rate** across thresholds.
# - **Interpretation:** Curve hugs the **top-left corner** with **AUC ≈ 1.0**, indicating near-perfect separability.
# - **Academic Justification:** Evaluates **ranking performance** independent of class imbalance. **AUC ≈ 1** means the model almost always assigns higher probabilities to malignant than benign cases.
#
# ---
#
# ## 3. Precision–Recall Curve (Classification)
#
# - **What it shows:** **Precision vs. Recall** across thresholds.
# - **Interpretation:** Both remain **high (>0.95)** across most thresholds, with minimal trade-off at extremes.
# - **Academic Justification:** More informative than ROC in **imbalanced settings**. High values confirm the classifier avoids both **false alarms** and **missed detections**, reinforcing robustness.
#
# ---
#
# ## 4. Residual Plot (Regression)
#
# - **What it shows:** **Predicted vs. true values** for the diabetes dataset with the **45° reference line**.
# - **Interpretation:** Predictions lie **below the line** at higher target values → systematic **underestimation** of severe progression.
# - **Academic Justification:** Reveals **bias** and potential **violations of linear model assumptions** (heteroscedasticity). Shows that linear regression **underfits complex nonlinear relationships**.
#
# ---
#
# ## 5. Distribution of Residuals (Regression)
#
# - **What it shows:** **Histogram + KDE** of regression errors.
# - **Interpretation:** Residuals are **centered at zero (unbiased)** but exhibit **wide spread** and **slight skewness**.
# - **Academic Justification:** Regression diagnostics expect residuals to approximate **$N(0, \sigma^2)$**. Deviations justify exploring **regularized or nonlinear models**, as documented in *Hastie et al., 2009*.
#
# ---
#
# ## 6. Barplot of Cross-Validation Scores
#
# - **What it shows:** Mean CV scores across **Accuracy, Precision, Recall, F1, and ROC AUC**.
# - **Interpretation:** Scores cluster tightly in the **0.97–0.99 range**, showing **consistent generalization** across folds.
# - **Academic Justification:** Cross-validation reduces **variance in performance estimation** and prevents misleading conclusions from a single split. Uniformity across metrics indicates **balanced performance**, aligning with best practices.
#
# ---
#
# ## 🎓 Unified Academic Conclusion
#
# Together, these visuals provide a **multi-dimensional evaluation framework**:
#
# - **Classification:** Confusion matrix + ROC + PR curves → quantify discrimination ability & error costs.
# - **Regression:** Residual plots + error distributions → expose model **bias, variance, and assumption violations**.
# - **Cross-validation barplots:** Validate **stability and generalization** across metrics.
#
# 👉 This **unified visualization suite** embodies the philosophy of the **Scoring API**: a **standardized, flexible, and rigorous** approach to quantifying predictive performance across tasks.
